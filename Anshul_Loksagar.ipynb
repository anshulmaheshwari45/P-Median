# %%
from gurobipy import*
import numpy as np
#i is the number of months
i=range(12)

#j is the production mode of normal production and 
j=range(2)

# k is the month sold
k=range(12)

#name of the months used for printing the results
names=['January','Feburary','March','April','May','June','July','August','September','October','November','December']

#name of the production mode used when printing results
modes=['Regular mode','Overtime']

#demand in each month
d_k=[800,900,1100,400,700,1100,700,900,800,700,800,1100]

#capacity constraint for each production mode
u_j=[800,200]

#cost of production
c_j=[10,12]

#storage cost per month
h=1

#perishable after 2 months
perishable=2

m=Model("Project2_question1")

x=m.addVars(i,j,k,vtype=GRB.INTEGER,name='Amount_produced_in_i_month_of_type_j_sold_in_month_k')


#assigning zero to values out of scope and d,f,g are used for iteration
for d in i:
    for f in j:
        for g in k:
            if g<d:
                m.addConstr(x[d,f,g]==0)
            elif g>d+perishable:
                m.addConstr(x[d,f,g]==0)

#production cost + storage cost
objective=quicksum(c_j[f]*(quicksum(x[d,f,g] for g in k for d in i)) for f in j)+quicksum(h*(g-d)*x[d,f,g] for d in i for f in j for g in k)

#objective function

m.setObjective(objective, GRB.MINIMIZE)

#demand constraint
m.addConstrs((quicksum(x[d,f,g] for f in j for d in i) == d_k[g] for g in k), name="Demandconstraint")

#capasity constraint
m.addConstrs((quicksum(x[d,f,g] for g in k)<=u_j[f] for f in j for d in i),name='capacityconstriant')

#non-negative constraint
m.addConstrs((x[d,f,g]>=0 for d in i for f in j for g in k),name="non_negativeconstraint")

m.optimize()

#printing optimal objective value
print("\n\n\nOptimal total production and storage cost for the next 12 months is equal to",m.objVal ,"dollar\n\n")

#representing answer in a structured way
for d in i:
    print("In",names[d],":")
    for f in j:
        for g in k:
            if g==d:
                print("\tProduce",x[d,f,g].X, "in",modes[f],"to be sold in",names[g])
            elif g==d+1:
                print("\tProduce",x[d,f,g].X, "in",modes[f],"to be sold in",names[g])
            elif g==d+2:
                print("\tProduce",x[d,f,g].X, "in",modes[f],"to be sold in",names[g])
            else:
                continue
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 546 rows, 288 columns and 1086 nonzeros
# Variable types: 0 continuous, 288 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 1e+03]
# Presolve removed 516 rows and 228 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 60 columns, 118 nonzeros
# Variable types: 0 continuous, 60 integer (0 binary)
# Found heuristic solution: objective 104888.00000
#
# Root relaxation: objective 1.021000e+05, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    102100.00000 102100.000  0.00%     -    0s
#
# Explored 0 nodes (13 simplex iterations) in 0.02 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 102100 104888
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.021000000000e+05, best bound 1.021000000000e+05, gap 0.0000%
#
#
#
# Optimal total production and storage cost for the next 12 months is equal to 102100.0 dollar
#
#
# In January :
# 	Produce 800.0 in Regular mode to be sold in January
# 	Produce -0.0 in Regular mode to be sold in Feburary
# 	Produce -0.0 in Regular mode to be sold in March
# 	Produce 0.0 in Overtime to be sold in January
# 	Produce -0.0 in Overtime to be sold in Feburary
# 	Produce -0.0 in Overtime to be sold in March
# In Feburary :
# 	Produce 700.0 in Regular mode to be sold in Feburary
# 	Produce 100.0 in Regular mode to be sold in March
# 	Produce -0.0 in Regular mode to be sold in April
# 	Produce 200.0 in Overtime to be sold in Feburary
# 	Produce -0.0 in Overtime to be sold in March
# 	Produce -0.0 in Overtime to be sold in April
# In March :
# 	Produce 800.0 in Regular mode to be sold in March
# 	Produce -0.0 in Regular mode to be sold in April
# 	Produce -0.0 in Regular mode to be sold in May
# 	Produce 200.0 in Overtime to be sold in March
# 	Produce -0.0 in Overtime to be sold in April
# 	Produce -0.0 in Overtime to be sold in May
# In April :
# 	Produce 400.0 in Regular mode to be sold in April
# 	Produce 200.0 in Regular mode to be sold in May
# 	Produce -0.0 in Regular mode to be sold in June
# 	Produce -0.0 in Overtime to be sold in April
# 	Produce -0.0 in Overtime to be sold in May
# 	Produce -0.0 in Overtime to be sold in June
# In May :
# 	Produce 500.0 in Regular mode to be sold in May
# 	Produce 300.0 in Regular mode to be sold in June
# 	Produce -0.0 in Regular mode to be sold in July
# 	Produce -0.0 in Overtime to be sold in May
# 	Produce -0.0 in Overtime to be sold in June
# 	Produce -0.0 in Overtime to be sold in July
# In June :
# 	Produce 800.0 in Regular mode to be sold in June
# 	Produce -0.0 in Regular mode to be sold in July
# 	Produce -0.0 in Regular mode to be sold in August
# 	Produce -0.0 in Overtime to be sold in June
# 	Produce -0.0 in Overtime to be sold in July
# 	Produce -0.0 in Overtime to be sold in August
# In July :
# 	Produce 700.0 in Regular mode to be sold in July
# 	Produce 100.0 in Regular mode to be sold in August
# 	Produce -0.0 in Regular mode to be sold in September
# 	Produce -0.0 in Overtime to be sold in July
# 	Produce -0.0 in Overtime to be sold in August
# 	Produce -0.0 in Overtime to be sold in September
# In August :
# 	Produce 800.0 in Regular mode to be sold in August
# 	Produce -0.0 in Regular mode to be sold in September
# 	Produce -0.0 in Regular mode to be sold in October
# 	Produce -0.0 in Overtime to be sold in August
# 	Produce -0.0 in Overtime to be sold in September
# 	Produce -0.0 in Overtime to be sold in October
# In September :
# 	Produce 800.0 in Regular mode to be sold in September
# 	Produce -0.0 in Regular mode to be sold in October
# 	Produce -0.0 in Regular mode to be sold in November
# 	Produce -0.0 in Overtime to be sold in September
# 	Produce -0.0 in Overtime to be sold in October
# 	Produce -0.0 in Overtime to be sold in November
# In October :
# 	Produce 700.0 in Regular mode to be sold in October
# 	Produce -0.0 in Regular mode to be sold in November
# 	Produce 100.0 in Regular mode to be sold in December
# 	Produce -0.0 in Overtime to be sold in October
# 	Produce -0.0 in Overtime to be sold in November
# 	Produce -0.0 in Overtime to be sold in December
# In November :
# 	Produce 800.0 in Regular mode to be sold in November
# 	Produce 0.0 in Regular mode to be sold in December
# 	Produce -0.0 in Overtime to be sold in November
# 	Produce -0.0 in Overtime to be sold in December
# In December :
# 	Produce 800.0 in Regular mode to be sold in December
# 	Produce 200.0 in Overtime to be sold in December

# %%
from numpy import*
from gurobipy import*
import math

#defining distance
distance={}

#r and t are used for iteration
r=0
t=0

#opening dat file and assigning it to f
f=open("PC001.dat")
for line in f:
    a=line.rstrip()
    if not len(a)>0:
        continue
    else:
        a=line.split()
        if a[0]=='N:':
            points=a[1]
        elif a[0]=='P:':
            r_centers=a[1]
        else:
            continue
#assigning the values read from dat file to n, c, and p so we can use it in further program

#number of points is given as n
n=int(points)

#number of candidate points for becoming center
c=int(points)

#number of centers we need
p=int(r_centers)

#the following set of code is used for importing distance data from dat file to distance array
f=open("PC001.dat")
for line in f:
    line=line.split()
    if not len(line)>3:
        continue
    else:
        for h in line:
            distance[r,t]=h
            t=t+1
        t=0
        r=r+1       
m=Model("IEMProject")

#add variables

#x is 1 if the point i is assigned to center j; otherwise zero
x={}

#y is 1 if the point j is a center
y={}

#z is the maximum distance between the point to its center
z=m.addVar(obj=1,vtype="C",name='z')

#add objective
m.setObjective(z, GRB.MINIMIZE)

#add variables
for j in range(c):
    y[j]=m.addVar(obj=0,vtype="B",name='y')
    for i in range(n):
        x[(i,j)]=m.addVar(obj=0,vtype="B",name='x')

#add constraints
for i in range(n):
    m.addConstr(y[i]+quicksum(x[(i,j)] for j in range(c)) ==1)
m.addConstr(quicksum(y[j] for j in range(c))==p)

for j in range(c):
    for i in range(n):
        m.addConstr(x[(i,j)] <= y[j])
        
for i in range(n):
    for j in range(c):
        m.addConstr(x[(i,j)]*distance[(i,j)] <= z)
        
        
m.optimize()
m.write("IEMProject.sol")
m.write("IEMProject.lp")

#printing soloution
if m.status == GRB.OPTIMAL:
        print("\n\n\nThe maximum distance between the non-center to its center is", m.objVal, "\n\n")
        for j in range(c):
            if y[j].X==1:
                print("The point", j+1, "is a center")
                for i in range(n):
                    if x[(i,j)].X==1:
                        print("\tThe non-center point", i+1, "is assigned to center point", j+1,", and the distance is",distance[(i,j)])
                    else:
                        continue
            else:
                continue
else:
    print('Optimum not found. Gurobi status code: ',m.status)
# Out:
# Optimize a model with 211 rows, 111 columns and 510 nonzeros
# Variable types: 1 continuous, 110 integer (110 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 906.0000000
# Presolve removed 26 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 185 rows, 98 columns, 455 nonzeros
# Variable types: 0 continuous, 98 integer (97 binary)
#
# Root relaxation: objective 2.308423e+01, 107 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   23.08423    0   87  906.00000   23.08423  97.5%     -    0s
# H    0     0                     805.0000000   23.08423  97.1%     -    0s
# H    0     0                     700.0000000   23.08423  96.7%     -    0s
# H    0     0                     467.0000000   23.08423  95.1%     -    0s
#      0     0   57.07047    0   40  467.00000   57.07047  87.8%     -    0s
# H    0     0                     416.0000000   57.07047  86.3%     -    0s
#      0     0   58.53141    0   37  416.00000   58.53141  85.9%     -    0s
# H    0     0                     398.0000000   58.53141  85.3%     -    0s
#      0     0   88.90600    0   35  398.00000   88.90600  77.7%     -    0s
# H    0     0                     259.0000000   88.90600  65.7%     -    0s
#      0     0  120.83835    0   27  259.00000  120.83835  53.3%     -    0s
#      0     0  120.83835    0   28  259.00000  120.83835  53.3%     -    0s
#      0     0  175.02081    0   17  259.00000  175.02081  32.4%     -    0s
# H    0     0                     257.0000000  175.02081  31.9%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 5
#
# Explored 1 nodes (373 simplex iterations) in 0.09 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 9: 257 259 398 ... 906
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.570000000000e+02, best bound 2.570000000000e+02, gap 0.0000%
# Warning: variables 2 and 3 have the same name "x"
# Warning: default variable names used to write solution file
# Warning: variables 2 and 3 have the same name "x"
# Warning: to let Gurobi read it back, use rlp format
#
#
#
# The maximum distance between the non-center to its center is 257.0
#
#
# The point 5 is a center
# 	The non-center point 2 is assigned to center point 5 , and the distance is 110
# 	The non-center point 4 is assigned to center point 5 , and the distance is 81
# The point 7 is a center
# 	The non-center point 1 is assigned to center point 7 , and the distance is 226
# 	The non-center point 3 is assigned to center point 7 , and the distance is 157
# 	The non-center point 6 is assigned to center point 7 , and the distance is 170
# 	The non-center point 8 is assigned to center point 7 , and the distance is 257
# 	The non-center point 9 is assigned to center point 7 , and the distance is 163
# The point 10 is a center

# %%
from numpy import*
from gurobipy import*
import math

#defining distance
distance={}

#r and t are used for iteration
r=0
t=0

#opening dat file and assigning it to f
f=open("PC002.dat")
for line in f:
    a=line.rstrip()
    if not len(a)>0:
        continue
    else:
        a=line.split()
        if a[0]=='N:':
            points=a[1]
        elif a[0]=='P:':
            r_centers=a[1]
        else:
            continue
#assigning the values read from dat file to n, c, and p so we can use it in further program

#number of points is given as n
n=int(points)

#number of candidate points for becoming center
c=int(points)

#number of centers we need
p=int(r_centers)

#the following set of code is used for importing distance data from dat file to distance array
f=open("PC002.dat")
for line in f:
    line=line.split()
    if not len(line)>3:
        continue
    else:
        for h in line:
            distance[r,t]=h
            t=t+1
        t=0
        r=r+1       
m=Model("IEMProject")

#add variables

#x is 1 if the point i is assigned to center j; otherwise zero
x={}

#y is 1 if the point j is a center
y={}

#z is the maximum distance between the point to its center
z=m.addVar(obj=1,vtype="C",name='z')

#add objective
m.setObjective(z, GRB.MINIMIZE)

#add variables
for j in range(c):
    y[j]=m.addVar(obj=0,vtype="B",name='y')
    for i in range(n):
        x[(i,j)]=m.addVar(obj=0,vtype="B",name='x')

#add constraints
for i in range(n):
    m.addConstr(y[i]+quicksum(x[(i,j)] for j in range(c)) ==1)
m.addConstr(quicksum(y[j] for j in range(c))==p)

for j in range(c):
    for i in range(n):
        m.addConstr(x[(i,j)] <= y[j])
        
for i in range(n):
    for j in range(c):
        m.addConstr(x[(i,j)]*distance[(i,j)] <= z)
        
        
m.optimize()
m.write("IEMProject.sol")
m.write("IEMProject.lp")

#printing soloution
if m.status == GRB.OPTIMAL:
        print("\n\n\nThe maximum distance between the non-center to its center is", m.objVal, "\n\n")
        for j in range(c):
            if y[j].X==1:
                print("The point", j+1, "is a center")
                for i in range(n):
                    if x[(i,j)].X==1:
                        print("\tThe non-center point", i+1, "is assigned to center point", j+1,", and the distance is",distance[(i,j)])
                    else:
                        continue
            else:
                continue
else:
    print('Optimum not found. Gurobi status code: ',m.status)
# Out:
# Optimize a model with 20101 rows, 10101 columns and 50100 nonzeros
# Variable types: 1 continuous, 10100 integer (10100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9919.0000000
# Presolve removed 109 rows and 8 columns
# Presolve time: 0.18s
# Presolved: 19992 rows, 10093 columns, 49974 nonzeros
# Variable types: 0 continuous, 10093 integer (10092 binary)
#
# Root relaxation: objective 1.307101e+01, 11427 iterations, 0.88 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 684 711 736 ... 931
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.840000000000e+02, best bound 6.840000000000e+02, gap 0.0000%
# Warning: variables 2 and 3 have the same name "x"
# Warning: default variable names used to write solution file
# Warning: variables 2 and 3 have the same name "x"
# Warning: to let Gurobi read it back, use rlp format
#
#
#
# The maximum distance between the non-center to its center is 684.0
#
#
# The point 1 is a center
# 	The non-center point 8 is assigned to center point 1 , and the distance is 354
# 	The non-center point 35 is assigned to center point 1 , and the distance is 411
# 	The non-center point 57 is assigned to center point 1 , and the distance is 280
# 	The non-center point 86 is assigned to center point 1 , and the distance is 195
# The point 2 is a center
# 	The non-center point 17 is assigned to center point 2 , and the distance is 363
# 	The non-center point 20 is assigned to center point 2 , and the distance is 655
# 	The non-center point 36 is assigned to center point 2 , and the distance is 460
# 	The non-center point 42 is assigned to center point 2 , and the distance is 233
# 	The non-center point 67 is assigned to center point 2 , and the distance is 662
# The point 6 is a center
# 	The non-center point 37 is assigned to center point 6 , and the distance is 447
# 	The non-center point 39 is assigned to center point 6 , and the distance is 512
# 	The non-center point 54 is assigned to center point 6 , and the distance is 282
# 	The non-center point 61 is assigned to center point 6 , and the distance is 61
# 	The non-center point 65 is assigned to center point 6 , and the distance is 212
# 	The non-center point 76 is assigned to center point 6 , and the distance is 164
# 	The non-center point 84 is assigned to center point 6 , and the distance is 622
# The point 14 is a center
# 	The non-center point 18 is assigned to center point 14 , and the distance is 252
# 	The non-center point 34 is assigned to center point 14 , and the distance is 29
# 	The non-center point 44 is assigned to center point 14 , and the distance is 588
# 	The non-center point 49 is assigned to center point 14 , and the distance is 325
# 	The non-center point 95 is assigned to center point 14 , and the distance is 488
# The point 19 is a center
# 	The non-center point 5 is assigned to center point 19 , and the distance is 602
# 	The non-center point 25 is assigned to center point 19 , and the distance is 174
# 	The non-center point 30 is assigned to center point 19 , and the distance is 684
# 	The non-center point 32 is assigned to center point 19 , and the distance is 121
# 	The non-center point 46 is assigned to center point 19 , and the distance is 537
# 	The non-center point 55 is assigned to center point 19 , and the distance is 641
# 	The non-center point 64 is assigned to center point 19 , and the distance is 563
# 	The non-center point 71 is assigned to center point 19 , and the distance is 171
# The point 23 is a center
# 	The non-center point 13 is assigned to center point 23 , and the distance is 212
# 	The non-center point 22 is assigned to center point 23 , and the distance is 164
# 	The non-center point 68 is assigned to center point 23 , and the distance is 276
# 	The non-center point 93 is assigned to center point 23 , and the distance is 618
# The point 26 is a center
# 	The non-center point 4 is assigned to center point 26 , and the distance is 364
# 	The non-center point 15 is assigned to center point 26 , and the distance is 676
# 	The non-center point 27 is assigned to center point 26 , and the distance is 117
# 	The non-center point 40 is assigned to center point 26 , and the distance is 603
# 	The non-center point 72 is assigned to center point 26 , and the distance is 195
# 	The non-center point 98 is assigned to center point 26 , and the distance is 209
# The point 28 is a center
# 	The non-center point 69 is assigned to center point 28 , and the distance is 153
# 	The non-center point 83 is assigned to center point 28 , and the distance is 449
# The point 33 is a center
# 	The non-center point 38 is assigned to center point 33 , and the distance is 551
# 	The non-center point 80 is assigned to center point 33 , and the distance is 549
# 	The non-center point 81 is assigned to center point 33 , and the distance is 467
# 	The non-center point 88 is assigned to center point 33 , and the distance is 408
# 	The non-center point 94 is assigned to center point 33 , and the distance is 306
# The point 41 is a center
# 	The non-center point 3 is assigned to center point 41 , and the distance is 516
# 	The non-center point 11 is assigned to center point 41 , and the distance is 566
# 	The non-center point 12 is assigned to center point 41 , and the distance is 477
# 	The non-center point 45 is assigned to center point 41 , and the distance is 505
# 	The non-center point 51 is assigned to center point 41 , and the distance is 648
# 	The non-center point 52 is assigned to center point 41 , and the distance is 606
# 	The non-center point 60 is assigned to center point 41 , and the distance is 253
# 	The non-center point 63 is assigned to center point 41 , and the distance is 129
# The point 62 is a center
# 	The non-center point 9 is assigned to center point 62 , and the distance is 399
# 	The non-center point 16 is assigned to center point 62 , and the distance is 1
# 	The non-center point 29 is assigned to center point 62 , and the distance is 515
# 	The non-center point 50 is assigned to center point 62 , and the distance is 1
# 	The non-center point 53 is assigned to center point 62 , and the distance is 71
# 	The non-center point 78 is assigned to center point 62 , and the distance is 221
# 	The non-center point 91 is assigned to center point 62 , and the distance is 172
# The point 75 is a center
# 	The non-center point 24 is assigned to center point 75 , and the distance is 436
# 	The non-center point 58 is assigned to center point 75 , and the distance is 183
# 	The non-center point 96 is assigned to center point 75 , and the distance is 442
# 	The non-center point 99 is assigned to center point 75 , and the distance is 568
# 	The non-center point 100 is assigned to center point 75 , and the distance is 546
# The point 79 is a center
# 	The non-center point 21 is assigned to center point 79 , and the distance is 603
# 	The non-center point 56 is assigned to center point 79 , and the distance is 668
# 	The non-center point 59 is assigned to center point 79 , and the distance is 681
# 	The non-center point 70 is assigned to center point 79 , and the distance is 587
# 	The non-center point 87 is assigned to center point 79 , and the distance is 186
# 	The non-center point 97 is assigned to center point 79 , and the distance is 264
# The point 82 is a center
# 	The non-center point 47 is assigned to center point 82 , and the distance is 361
# 	The non-center point 48 is assigned to center point 82 , and the distance is 57
# 	The non-center point 74 is assigned to center point 82 , and the distance is 322
# 	The non-center point 77 is assigned to center point 82 , and the distance is 185
# 	The non-center point 85 is assigned to center point 82 , and the distance is 597
# 	The non-center point 89 is assigned to center point 82 , and the distance is 331
# 	The non-center point 92 is assigned to center point 82 , and the distance is 283
# The point 90 is a center
# 	The non-center point 7 is assigned to center point 90 , and the distance is 617
# 	The non-center point 10 is assigned to center point 90 , and the distance is 19
# 	The non-center point 31 is assigned to center point 90 , and the distance is 224
# 	The non-center point 43 is assigned to center point 90 , and the distance is 463
# 	The non-center point 66 is assigned to center point 90 , and the distance is 459
# 	The non-center point 73 is assigned to center point 90 , and the distance is 146

# %%
from numpy import*
from gurobipy import*
import math

#defining distance
distance={}

#r and t are used for iteration
r=0
t=0

#opening dat file and assigning it to f
f=open("PC003.dat")
for line in f:
    a=line.rstrip()
    if not len(a)>0:
        continue
    else:
        a=line.split()
        if a[0]=='N:':
            points=a[1]
        elif a[0]=='P:':
            r_centers=a[1]
        else:
            continue
#assigning the values read from dat file to n, c, and p so we can use it in further program

#number of points is given as n
n=int(points)

#number of candidate points for becoming center
c=int(points)

#number of centers we need
p=int(r_centers)

#the following set of code is used for importing distance data from dat file to distance array
f=open("PC003.dat")
for line in f:
    line=line.split()
    if not len(line)>3:
        continue
    else:
        for h in line:
            distance[r,t]=h
            t=t+1
        t=0
        r=r+1       
m=Model("IEMProject")

#add variables

#x is 1 if the point i is assigned to center j; otherwise zero
x={}

#y is 1 if the point j is a center
y={}

#z is the maximum distance between the point to its center
z=m.addVar(obj=1,vtype="C",name='z')

#add objective
m.setObjective(z, GRB.MINIMIZE)

m.params.timelimit = 600

#add variables
for j in range(c):
    y[j]=m.addVar(obj=0,vtype="B",name='y')
    for i in range(n):
        x[(i,j)]=m.addVar(obj=0,vtype="B",name='x')

#add constraints
for i in range(n):
    m.addConstr(y[i]+quicksum(x[(i,j)] for j in range(c)) ==1)
m.addConstr(quicksum(y[j] for j in range(c))==p)

for j in range(c):
    for i in range(n):
        m.addConstr(x[(i,j)] <= y[j])
        
for i in range(n):
    for j in range(c):
        m.addConstr(x[(i,j)]*distance[(i,j)] <= z)
        
m.optimize()        
m.write("IEMProject.sol")
m.write("IEMProject.lp")

#printing soloution

if m.status == GRB.OPTIMAL:
    print("do nothing")
else:
    print("\n\n\nThe maximum distance between the non-center to its center is", m.objVal, "\n\n")
    for j in range(c):
        if y[j].X==1:
            print("The point", j+1, "is a center")
            for i in range(n):
                if x[(i,j)].X==1:
                    print("\tThe non-center point", i+1, "is assigned to center point", j+1,", and the distance is",distance[(i,j)])
                else:
                    continue
        else:
            continue
# Out:
# Changed value of parameter timelimit to 600.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 80201 rows, 40201 columns and 200200 nonzeros
# Variable types: 1 continuous, 40200 integer (40200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 19982.000000
# Presolve removed 209 rows and 8 columns
# Presolve time: 0.79s
# Presolved: 79992 rows, 40193 columns, 199974 nonzeros
# Variable types: 0 continuous, 40193 integer (40192 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    40762    8.9055486e+00   3.177043e+03   0.000000e+00      6s
#    43376    1.1699155e+01   1.023347e+03   0.000000e+00     11s
#    45445    1.2673915e+01   7.130612e+02   0.000000e+00     15s
#    48151    1.3117957e+01   1.119308e+01   0.000000e+00     20s
#    48252    1.2965667e+01   0.000000e+00   0.000000e+00     21s
#
# Root relaxation: objective 1.296567e+01, 48252 iterations, 19.55 seconds
# Total elapsed time = 27.01s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   13.61843    0 37011 19982.0000   13.61843   100%     -   39s
# H    0     0                    4632.0000000   13.61843   100%     -   40s
#      0     0   19.93700    0 8778 4632.00000   19.93700   100%     -  129s
#      0     0   38.03718    0 7533 4632.00000   38.03718  99.2%     -  197s
# H    0     0                    3496.0000000   38.03718  98.9%     -  197s
#      0     0   40.85671    0 5970 3496.00000   40.85671  98.8%     -  201s
#      0     0   40.85671    0 5970 3496.00000   40.85671  98.8%     -  202s
# H    0     0                    3306.0000000   40.85671  98.8%     -  222s
# H    0     0                    3204.0000000   40.85671  98.7%     -  223s
# H    0     0                    3005.0000000   40.85671  98.6%     -  223s
#   1533  1057  269.00000  815 1344 1927.00000  181.00000  90.6%   721  503s
#   1663  1160  278.00000  871 1247 1927.00000  181.00000  90.6%   703  510s
# H 1810  1158                    1836.0000000  181.00000  90.1%   681  524s
#   1812  1157  312.37410  926 1051 1836.00000  181.00000  90.1%   682  531s
#   1999  1266  413.00000 1001  851 1836.00000  188.64820  89.7%   653  539s
# H 2174  1104                    1633.0000000  189.00000  88.4%   631  573s
#   2175  1104 1276.00000  783 8778 1633.00000  189.00000  88.4%   631  575s
#   2177  1105 1429.00000  252 1785 1633.00000  277.00000  83.0%   630  580s
#   2189  1113 1426.00000 1010 2073 1633.00000  330.67788  79.8%   627  585s
#   2201  1121 1219.00000 1064 1919 1633.00000  351.57978  78.5%   623  591s
#   2211  1128 1394.00000  249 2001 1633.00000  396.49735  75.7%   620  596s
#
# Cutting planes:
#   Implied bound: 3
#   MIR: 509
#   Flow cover: 1559
#   Zero half: 67
#
# Explored 2217 nodes (1697416 simplex iterations) in 600.03 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 1633 1836 1927 ... 2343
#
# Time limit reached
# Best objective 1.633000000000e+03, best bound 4.110000000000e+02, gap 74.8316%
# Warning: variables 2 and 3 have the same name "x"
# Warning: default variable names used to write solution file
# Warning: variables 2 and 3 have the same name "x"
# Warning: to let Gurobi read it back, use rlp format
#
#
#
# The maximum distance between the non-center to its center is 1633.0
#
#
# The point 20 is a center
# 	The non-center point 14 is assigned to center point 20 , and the distance is 1633
# 	The non-center point 41 is assigned to center point 20 , and the distance is 439
# 	The non-center point 78 is assigned to center point 20 , and the distance is 1547
# 	The non-center point 176 is assigned to center point 20 , and the distance is 647
# The point 28 is a center
# 	The non-center point 49 is assigned to center point 28 , and the distance is 591
# 	The non-center point 68 is assigned to center point 28 , and the distance is 580
# 	The non-center point 83 is assigned to center point 28 , and the distance is 311
# 	The non-center point 87 is assigned to center point 28 , and the distance is 159
# 	The non-center point 106 is assigned to center point 28 , and the distance is 254
# 	The non-center point 136 is assigned to center point 28 , and the distance is 1493
# The point 31 is a center
# 	The non-center point 130 is assigned to center point 31 , and the distance is 882
# 	The non-center point 160 is assigned to center point 31 , and the distance is 1039
# 	The non-center point 174 is assigned to center point 31 , and the distance is 1503
# The point 42 is a center
# 	The non-center point 1 is assigned to center point 42 , and the distance is 316
# 	The non-center point 34 is assigned to center point 42 , and the distance is 186
# 	The non-center point 37 is assigned to center point 42 , and the distance is 485
# 	The non-center point 46 is assigned to center point 42 , and the distance is 1588
# 	The non-center point 47 is assigned to center point 42 , and the distance is 1448
# 	The non-center point 57 is assigned to center point 42 , and the distance is 128
# 	The non-center point 59 is assigned to center point 42 , and the distance is 360
# 	The non-center point 60 is assigned to center point 42 , and the distance is 589
# 	The non-center point 65 is assigned to center point 42 , and the distance is 1314
# 	The non-center point 98 is assigned to center point 42 , and the distance is 579
# 	The non-center point 113 is assigned to center point 42 , and the distance is 1349
# 	The non-center point 120 is assigned to center point 42 , and the distance is 618
# 	The non-center point 125 is assigned to center point 42 , and the distance is 999
# 	The non-center point 168 is assigned to center point 42 , and the distance is 1573
# 	The non-center point 172 is assigned to center point 42 , and the distance is 1630
# 	The non-center point 186 is assigned to center point 42 , and the distance is 1396
# 	The non-center point 191 is assigned to center point 42 , and the distance is 173
# The point 44 is a center
# 	The non-center point 29 is assigned to center point 44 , and the distance is 1122
# 	The non-center point 32 is assigned to center point 44 , and the distance is 1477
# 	The non-center point 140 is assigned to center point 44 , and the distance is 408
# 	The non-center point 149 is assigned to center point 44 , and the distance is 535
# 	The non-center point 158 is assigned to center point 44 , and the distance is 27
# 	The non-center point 169 is assigned to center point 44 , and the distance is 1572
# 	The non-center point 170 is assigned to center point 44 , and the distance is 642
# 	The non-center point 190 is assigned to center point 44 , and the distance is 603
# The point 45 is a center
# 	The non-center point 5 is assigned to center point 45 , and the distance is 770
# 	The non-center point 164 is assigned to center point 45 , and the distance is 586
# 	The non-center point 194 is assigned to center point 45 , and the distance is 1170
# 	The non-center point 195 is assigned to center point 45 , and the distance is 1473
# The point 55 is a center
# 	The non-center point 26 is assigned to center point 55 , and the distance is 508
# 	The non-center point 70 is assigned to center point 55 , and the distance is 983
# 	The non-center point 86 is assigned to center point 55 , and the distance is 855
# 	The non-center point 90 is assigned to center point 55 , and the distance is 893
# 	The non-center point 105 is assigned to center point 55 , and the distance is 778
# 	The non-center point 107 is assigned to center point 55 , and the distance is 564
# 	The non-center point 118 is assigned to center point 55 , and the distance is 424
# 	The non-center point 129 is assigned to center point 55 , and the distance is 328
# 	The non-center point 153 is assigned to center point 55 , and the distance is 1602
# 	The non-center point 183 is assigned to center point 55 , and the distance is 39
# The point 61 is a center
# 	The non-center point 2 is assigned to center point 61 , and the distance is 1413
# 	The non-center point 12 is assigned to center point 61 , and the distance is 422
# 	The non-center point 33 is assigned to center point 61 , and the distance is 371
# 	The non-center point 40 is assigned to center point 61 , and the distance is 218
# 	The non-center point 67 is assigned to center point 61 , and the distance is 867
# 	The non-center point 76 is assigned to center point 61 , and the distance is 1531
# 	The non-center point 127 is assigned to center point 61 , and the distance is 489
# 	The non-center point 133 is assigned to center point 61 , and the distance is 3
# 	The non-center point 157 is assigned to center point 61 , and the distance is 1175
# The point 62 is a center
# 	The non-center point 8 is assigned to center point 62 , and the distance is 1282
# 	The non-center point 24 is assigned to center point 62 , and the distance is 341
# 	The non-center point 69 is assigned to center point 62 , and the distance is 1044
# 	The non-center point 91 is assigned to center point 62 , and the distance is 1426
# The point 74 is a center
# 	The non-center point 81 is assigned to center point 74 , and the distance is 93
# 	The non-center point 82 is assigned to center point 74 , and the distance is 616
# 	The non-center point 111 is assigned to center point 74 , and the distance is 373
# 	The non-center point 173 is assigned to center point 74 , and the distance is 14
# The point 77 is a center
# 	The non-center point 11 is assigned to center point 77 , and the distance is 311
# 	The non-center point 48 is assigned to center point 77 , and the distance is 624
# 	The non-center point 85 is assigned to center point 77 , and the distance is 576
# 	The non-center point 101 is assigned to center point 77 , and the distance is 798
# 	The non-center point 146 is assigned to center point 77 , and the distance is 254
# 	The non-center point 187 is assigned to center point 77 , and the distance is 1343
# The point 79 is a center
# 	The non-center point 17 is assigned to center point 79 , and the distance is 1599
# 	The non-center point 19 is assigned to center point 79 , and the distance is 329
# 	The non-center point 22 is assigned to center point 79 , and the distance is 246
# 	The non-center point 25 is assigned to center point 79 , and the distance is 509
# 	The non-center point 38 is assigned to center point 79 , and the distance is 995
# 	The non-center point 64 is assigned to center point 79 , and the distance is 1384
# 	The non-center point 117 is assigned to center point 79 , and the distance is 1485
# 	The non-center point 119 is assigned to center point 79 , and the distance is 1507
# 	The non-center point 126 is assigned to center point 79 , and the distance is 718
# 	The non-center point 134 is assigned to center point 79 , and the distance is 871
# The point 92 is a center
# 	The non-center point 23 is assigned to center point 92 , and the distance is 1174
# 	The non-center point 50 is assigned to center point 92 , and the distance is 527
# 	The non-center point 108 is assigned to center point 92 , and the distance is 777
# 	The non-center point 142 is assigned to center point 92 , and the distance is 1315
# 	The non-center point 150 is assigned to center point 92 , and the distance is 83
# The point 102 is a center
# 	The non-center point 9 is assigned to center point 102 , and the distance is 1435
# 	The non-center point 21 is assigned to center point 102 , and the distance is 140
# 	The non-center point 36 is assigned to center point 102 , and the distance is 845
# 	The non-center point 104 is assigned to center point 102 , and the distance is 1268
# 	The non-center point 137 is assigned to center point 102 , and the distance is 1172
# 	The non-center point 144 is assigned to center point 102 , and the distance is 1276
# 	The non-center point 148 is assigned to center point 102 , and the distance is 952
# 	The non-center point 192 is assigned to center point 102 , and the distance is 894
# 	The non-center point 196 is assigned to center point 102 , and the distance is 1085
# 	The non-center point 198 is assigned to center point 102 , and the distance is 1595
# The point 114 is a center
# 	The non-center point 56 is assigned to center point 114 , and the distance is 642
# 	The non-center point 58 is assigned to center point 114 , and the distance is 787
# 	The non-center point 71 is assigned to center point 114 , and the distance is 861
# 	The non-center point 73 is assigned to center point 114 , and the distance is 30
# 	The non-center point 89 is assigned to center point 114 , and the distance is 35
# 	The non-center point 94 is assigned to center point 114 , and the distance is 1609
# 	The non-center point 95 is assigned to center point 114 , and the distance is 1562
# 	The non-center point 128 is assigned to center point 114 , and the distance is 1393
# 	The non-center point 139 is assigned to center point 114 , and the distance is 121
# 	The non-center point 159 is assigned to center point 114 , and the distance is 824
# 	The non-center point 161 is assigned to center point 114 , and the distance is 1493
# 	The non-center point 180 is assigned to center point 114 , and the distance is 149
# The point 115 is a center
# 	The non-center point 18 is assigned to center point 115 , and the distance is 776
# 	The non-center point 88 is assigned to center point 115 , and the distance is 1612
# 	The non-center point 155 is assigned to center point 115 , and the distance is 577
# 	The non-center point 165 is assigned to center point 115 , and the distance is 422
# 	The non-center point 185 is assigned to center point 115 , and the distance is 1340
# The point 116 is a center
# 	The non-center point 10 is assigned to center point 116 , and the distance is 274
# 	The non-center point 51 is assigned to center point 116 , and the distance is 1305
# 	The non-center point 52 is assigned to center point 116 , and the distance is 327
# 	The non-center point 75 is assigned to center point 116 , and the distance is 174
# 	The non-center point 80 is assigned to center point 116 , and the distance is 302
# 	The non-center point 138 is assigned to center point 116 , and the distance is 14
# 	The non-center point 141 is assigned to center point 116 , and the distance is 364
# 	The non-center point 143 is assigned to center point 116 , and the distance is 1532
# 	The non-center point 163 is assigned to center point 116 , and the distance is 567
# 	The non-center point 188 is assigned to center point 116 , and the distance is 889
# 	The non-center point 197 is assigned to center point 116 , and the distance is 637
# The point 121 is a center
# 	The non-center point 13 is assigned to center point 121 , and the distance is 342
# 	The non-center point 35 is assigned to center point 121 , and the distance is 1270
# 	The non-center point 66 is assigned to center point 121 , and the distance is 1034
# 	The non-center point 72 is assigned to center point 121 , and the distance is 1062
# 	The non-center point 84 is assigned to center point 121 , and the distance is 1053
# 	The non-center point 99 is assigned to center point 121 , and the distance is 354
# 	The non-center point 110 is assigned to center point 121 , and the distance is 1209
# 	The non-center point 112 is assigned to center point 121 , and the distance is 601
# 	The non-center point 123 is assigned to center point 121 , and the distance is 958
# 	The non-center point 152 is assigned to center point 121 , and the distance is 59
# 	The non-center point 171 is assigned to center point 121 , and the distance is 907
# The point 122 is a center
# 	The non-center point 3 is assigned to center point 122 , and the distance is 1363
# 	The non-center point 43 is assigned to center point 122 , and the distance is 984
# 	The non-center point 167 is assigned to center point 122 , and the distance is 533
# 	The non-center point 193 is assigned to center point 122 , and the distance is 422
# The point 132 is a center
# 	The non-center point 16 is assigned to center point 132 , and the distance is 1355
# 	The non-center point 97 is assigned to center point 132 , and the distance is 392
# 	The non-center point 103 is assigned to center point 132 , and the distance is 1102
# 	The non-center point 109 is assigned to center point 132 , and the distance is 938
# 	The non-center point 181 is assigned to center point 132 , and the distance is 1622
# 	The non-center point 182 is assigned to center point 132 , and the distance is 544
# The point 145 is a center
# 	The non-center point 15 is assigned to center point 145 , and the distance is 1510
# 	The non-center point 39 is assigned to center point 145 , and the distance is 1332
# 	The non-center point 54 is assigned to center point 145 , and the distance is 13
# 	The non-center point 131 is assigned to center point 145 , and the distance is 541
# The point 154 is a center
# 	The non-center point 4 is assigned to center point 154 , and the distance is 1439
# 	The non-center point 6 is assigned to center point 154 , and the distance is 1235
# 	The non-center point 53 is assigned to center point 154 , and the distance is 616
# 	The non-center point 63 is assigned to center point 154 , and the distance is 875
# 	The non-center point 100 is assigned to center point 154 , and the distance is 350
# 	The non-center point 135 is assigned to center point 154 , and the distance is 121
# 	The non-center point 147 is assigned to center point 154 , and the distance is 1354
# 	The non-center point 156 is assigned to center point 154 , and the distance is 23
# 	The non-center point 178 is assigned to center point 154 , and the distance is 692
# 	The non-center point 179 is assigned to center point 154 , and the distance is 1437
# The point 166 is a center
# 	The non-center point 27 is assigned to center point 166 , and the distance is 1614
# 	The non-center point 30 is assigned to center point 166 , and the distance is 1617
# 	The non-center point 93 is assigned to center point 166 , and the distance is 313
# 	The non-center point 151 is assigned to center point 166 , and the distance is 1026
# 	The non-center point 162 is assigned to center point 166 , and the distance is 1334
# 	The non-center point 177 is assigned to center point 166 , and the distance is 955
# The point 184 is a center
# 	The non-center point 7 is assigned to center point 184 , and the distance is 1175
# 	The non-center point 124 is assigned to center point 184 , and the distance is 1050
# 	The non-center point 175 is assigned to center point 184 , and the distance is 268
# The point 199 is a center
# 	The non-center point 96 is assigned to center point 199 , and the distance is 820
# 	The non-center point 189 is assigned to center point 199 , and the distance is 100
# 	The non-center point 200 is assigned to center point 199 , and the distance is 1004
